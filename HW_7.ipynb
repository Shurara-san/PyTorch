# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df_test = pd.read_csv("drive/MyDrive/Colab Notebooks/PyTorch_Lesson6/test.csv")
df_train = pd.read_csv("drive/MyDrive/Colab Notebooks/PyTorch_Lesson6/train.csv")

# %%
df_train
# Out:
#           id  label                                              tweet
# 0          1      0   @user when a father is dysfunctional and is s...
# 1          2      0  @user @user thanks for #lyft credit i can't us...
# 2          3      0                                bihday your majesty
# 3          4      0  #model   i love u take with u all the time in ...
# 4          5      0             factsguide: society now    #motivation
# ...      ...    ...                                                ...
# 31957  31958      0  ate @user isz that youuu?ðððððð...
# 31958  31959      0    to see nina turner on the airwaves trying to...
# 31959  31960      0  listening to sad songs on a monday morning otw...
# 31960  31961      1  @user #sikh #temple vandalised in in #calgary,...
# 31961  31962      0                   thank you @user for you follow
#
# [31962 rows x 3 columns]

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(df_train[['id', 'tweet']], df_train['label'], test_size=0.33, random_state=42)

# %%
df_train = X_train
df_train['label'] = y_train
df_train
# Out:
#           id                                              tweet  label
# 18780  18781  bbc news - russia lake syamozero: children die...      0
# 18475  18476  @user is going to get sick of my face! #firebr...      0
# 15842  15843  can't wait until tomorrow night! #weekend #sum...      0
# 22997  22998  we are so   for the 2nd annual bailey day tast...      0
# 3560    3561  i got addicted. moonblue was my name  ...took ...      0
# ...      ...                                                ...    ...
# 29802  29803  #waltdisneyreso  should be ashamed of themselv...      0
# 5390    5391   @user invited @user over for a catch up and i...      0
# 860      861  black professor makes assumptions about an ent...      1
# 15795  15796  #lgbtqhatetrumppay is total #liberal trash. it...      0
# 23654  23655  what makes people   is relative. we have our w...      0
#
# [21414 rows x 3 columns]

# %%
df_val = X_val
df_val['label'] = y_val
df_val
# Out:
#           id                                              tweet  label
# 12227  12228   @user âmy mom says my smile is captivatingâ...      0
# 14709  14710  in 3 days i will be meeting my sis-n-law, coun...      0
# 19319  19320  hating the conservative homophobes using this ...      0
# 4308    4309  awee if this doesn't  #scream   #friday #acewe...      0
# 24055  24056   fathersday  #fatherÃ¢ÂÂs #day #god! #ÃÂ« #...      0
# ...      ...                                                ...    ...
# 16235  16236  wonder if dt is still demanding the rnc to boo...      0
# 31460  31461  you might be a libtard if... #libtard  #sjw #l...      1
# 1760    1761  this #newyearseve,may our #resolutions b 2 end...      1
# 24683  24684                      congrats on the hard work!!        0
# 22629  22630  june is a #celebration month   bihdays to all ...      0
#
# [10548 rows x 3 columns]

# %%
#!pip install stop-words pymorphy2
#!pip install nltk

from nltk.tokenize import word_tokenize

# %%
import re

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
puncts = {'!', '"', '#','$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.',
'/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{',
'|', '}', '~'}

# %%
def preprocess_text(txt):
    txt = re.sub(r'@\w+ ', "", txt)
    txt = str(word_tokenize(txt))
    txt = txt.lower()
    # txt = [morpher.parse(word)[0].normal_form for word in txt.split() if word not in sw]
    txt = "".join(c for c in txt if c not in puncts)
    return txt

# %%
df_train['tweet'].iloc[:1].apply(preprocess_text).values
# Out:
# array(['bbc news  russia lake syamozero  children die after storm catches boating group  poorkids'],
#       dtype=object)

# %%
from tqdm import tqdm 
tqdm.pandas()

df_train['tweet'] = df_train['tweet'].progress_apply(preprocess_text)
df_val['tweet'] = df_val['tweet'].progress_apply(preprocess_text)
# Out:
# 100%|██████████| 21414/21414 [00:05<00:00, 3903.43it/s]
# 100%|██████████| 10548/10548 [00:02<00:00, 3836.42it/s]

# %%
train_corpus = " ".join(df_train["tweet"])
train_corpus = train_corpus.lower()

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download("punkt")

tokens = word_tokenize(train_corpus)
tokens[:5]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['bbc', 'news', 'russia', 'lake', 'syamozero']

# %%
tokens_filtered = [word for word in tokens if word.isalnum()]

# %%
from nltk.probability import FreqDist

max_words = 2000

dist = FreqDist(tokens_filtered)
tokens_filtered_top = [pair[0] for pair in dist.most_common(max_words-1)]  # вычитание 1 для padding
len(tokens_filtered_top)
# Out:
# 1999

# %%
tokens_filtered_top[:10]
# Out:
# ['the', 'to', 'i', 'a', 'you', 'and', 'in', 'for', 'is', 'of']

# %%
vocabulary = {v: k for k, v in dict(enumerate(tokens_filtered_top, 1)).items()}
vocabulary
# Out:
# {'the': 1,
#  'to': 2,
#  'i': 3,
#  'a': 4,
#  'you': 5,
#  'and': 6,
#  'in': 7,
#  'for': 8,
#  'is': 9,
#  'of': 10,
#  'my': 11,
#  'it': 12,
#  's': 13,
#  'love': 14,
#  'on': 15,
#  'this': 16,
#  'with': 17,
#  'be': 18,
#  'nt': 19,
#  'day': 20,
#  'that': 21,
#  'so': 22,
#  'all': 23,
#  'are': 24,
#  'me': 25,
#  'do': 26,
#  'amp': 27,
#  'happy': 28,
#  'your': 29,
#  'have': 30,
#  'at': 31,
#  'we': 32,
#  'just': 33,
#  'when': 34,
#  'not': 35,
#  'will': 36,
#  'am': 37,
#  'u': 38,
#  'what': 39,
#  'time': 40,
#  'life': 41,
#  'today': 42,
#  'but': 43,
#  'from': 44,
#  'm': 45,
#  'like': 46,
#  'up': 47,
#  'new': 48,
#  'thankful': 49,
#  'positive': 50,
#  'was': 51,
#  'now': 52,
#  'out': 53,
#  'as': 54,
#  'get': 55,
#  'how': 56,
#  'by': 57,
#  'people': 58,
#  'good': 59,
#  'our': 60,
#  'bihday': 61,
#  'about': 62,
#  'no': 63,
#  'they': 64,
#  'one': 65,
#  'ca': 66,
#  'see': 67,
#  'can': 68,
#  'more': 69,
#  'if': 70,
#  'smile': 71,
#  'go': 72,
#  'who': 73,
#  'want': 74,
#  'work': 75,
#  'take': 76,
#  'has': 77,
#  'healthy': 78,
#  'he': 79,
#  'user': 80,
#  'father': 81,
#  'weekend': 82,
#  'fun': 83,
#  'an': 84,
#  'got': 85,
#  'there': 86,
#  're': 87,
#  'make': 88,
#  'summer': 89,
#  '2': 90,
#  'us': 91,
#  'great': 92,
#  'family': 93,
#  'friday': 94,
#  'best': 95,
#  'or': 96,
#  'beautiful': 97,
#  'here': 98,
#  'why': 99,
#  'his': 100,
#  'days': 101,
#  'need': 102,
#  'way': 103,
#  'only': 104,
#  'friends': 105,
#  'bull': 106,
#  'wait': 107,
#  'first': 108,
#  'going': 109,
#  'music': 110,
#  'really': 111,
#  'their': 112,
#  'morning': 113,
#  'back': 114,
#  'very': 115,
#  'been': 116,
#  'world': 117,
#  'know': 118,
#  'week': 119,
#  'orlando': 120,
#  'cute': 121,
#  'some': 122,
#  'tomorrow': 123,
#  'fathersday': 124,
#  'sad': 125,
#  'think': 126,
#  'her': 127,
#  'never': 128,
#  'trump': 129,
#  'did': 130,
#  'much': 131,
#  'happiness': 132,
#  'affirmation': 133,
#  'off': 134,
#  'being': 135,
#  'after': 136,
#  'night': 137,
#  '3': 138,
#  'feel': 139,
#  'model': 140,
#  'too': 141,
#  'sunday': 142,
#  'iam': 143,
#  'girl': 144,
#  'always': 145,
#  'home': 146,
#  'blog': 147,
#  'had': 148,
#  'live': 149,
#  'right': 150,
#  've': 151,
#  'because': 152,
#  'amazing': 153,
#  'last': 154,
#  'she': 155,
#  'next': 156,
#  'come': 157,
#  'finally': 158,
#  'tonight': 159,
#  'even': 160,
#  'ðx9fx98x99ðx9fx98x8eðx9fx91x84ðx9fx91': 161,
#  'over': 162,
#  'fathers': 163,
#  'well': 164,
#  'than': 165,
#  'them': 166,
#  'gold': 167,
#  'find': 168,
#  'selfie': 169,
#  'still': 170,
#  'makes': 171,
#  'these': 172,
#  'ready': 173,
#  'âx86x9d': 174,
#  'dad': 175,
#  'things': 176,
#  'follow': 177,
#  'silver': 178,
#  'everyone': 179,
#  'look': 180,
#  'thanks': 181,
#  'thank': 182,
#  'year': 183,
#  'altwaystoheal': 184,
#  'then': 185,
#  'little': 186,
#  'show': 187,
#  'would': 188,
#  'does': 189,
#  'man': 190,
#  'feeling': 191,
#  'watch': 192,
#  'looking': 193,
#  '1': 194,
#  'na': 195,
#  'let': 196,
#  '4': 197,
#  'free': 198,
#  'ever': 199,
#  'via': 200,
#  'again': 201,
#  'girls': 202,
#  'pay': 203,
#  'forex': 204,
#  'many': 205,
#  'food': 206,
#  'gt': 207,
#  'him': 208,
#  'should': 209,
#  'peace': 210,
#  'most': 211,
#  'another': 212,
#  'd': 213,
#  'hope': 214,
#  'sun': 215,
#  'll': 216,
#  'game': 217,
#  'blessed': 218,
#  'hate': 219,
#  'its': 220,
#  'enjoy': 221,
#  'down': 222,
#  '2016': 223,
#  'stop': 224,
#  'getting': 225,
#  'friend': 226,
#  'bear': 227,
#  'news': 228,
#  'city': 229,
#  'climb': 230,
#  'say': 231,
#  'old': 232,
#  'baby': 233,
#  'sta': 234,
#  'made': 235,
#  'god': 236,
#  'black': 237,
#  'every': 238,
#  'saturday': 239,
#  'white': 240,
#  'help': 241,
#  'dog': 242,
#  'someone': 243,
#  'whatever': 244,
#  'funny': 245,
#  'instagood': 246,
#  'before': 247,
#  'could': 248,
#  'keep': 249,
#  'polar': 250,
#  'hea': 251,
#  'into': 252,
#  'coming': 253,
#  'where': 254,
#  'may': 255,
#  'lol': 256,
#  'better': 257,
#  'might': 258,
#  'having': 259,
#  'any': 260,
#  'video': 261,
#  'angry': 262,
#  'wedding': 263,
#  'believe': 264,
#  'guys': 265,
#  'true': 266,
#  'excited': 267,
#  'kids': 268,
#  'soon': 269,
#  'school': 270,
#  'nothing': 271,
#  'until': 272,
#  'done': 273,
#  'quote': 274,
#  'were': 275,
#  'nice': 276,
#  'healing': 277,
#  'years': 278,
#  'lt': 279,
#  'awesome': 280,
#  'motivation': 281,
#  'long': 282,
#  'women': 283,
#  'beach': 284,
#  'proud': 285,
#  'waiting': 286,
#  'please': 287,
#  'team': 288,
#  'around': 289,
#  'america': 290,
#  'holiday': 291,
#  'two': 292,
#  'big': 293,
#  'attack': 294,
#  'lost': 295,
#  'found': 296,
#  'other': 297,
#  'something': 298,
#  'rip': 299,
#  'bad': 300,
#  'end': 301,
#  'such': 302,
#  'real': 303,
#  'n': 304,
#  'direct': 305,
#  'grateful': 306,
#  'play': 307,
#  'monday': 308,
#  'place': 309,
#  'travel': 310,
#  'change': 311,
#  'yes': 312,
#  'check': 313,
#  'own': 314,
#  'left': 315,
#  'forward': 316,
#  '5': 317,
#  'thing': 318,
#  'dominate': 319,
#  'watching': 320,
#  'fashion': 321,
#  'yeah': 322,
#  'face': 323,
#  'without': 324,
#  'doing': 325,
#  'give': 326,
#  'oh': 327,
#  'strong': 328,
#  'photooftheday': 329,
#  'hard': 330,
#  'racing': 331,
#  'miss': 332,
#  'cool': 333,
#  'person': 334,
#  'those': 335,
#  'mindset': 336,
#  'wish': 337,
#  'sex': 338,
#  'r': 339,
#  'playing': 340,
#  'followme': 341,
#  'lovely': 342,
#  'hair': 343,
#  'libtard': 344,
#  'hot': 345,
#  'ðx9fx98x8d': 346,
#  'bing': 347,
#  'away': 348,
#  'boy': 349,
#  'win': 350,
#  'ur': 351,
#  'bong': 352,
#  'weeks': 353,
#  '10': 354,
#  'leave': 355,
#  'lot': 356,
#  'twitter': 357,
#  'wow': 358,
#  'health': 359,
#  'everything': 360,
#  'ðx9fx98x8a': 361,
#  'joy': 362,
#  'living': 363,
#  'success': 364,
#  'book': 365,
#  'buffalo': 366,
#  'im': 367,
#  'yet': 368,
#  'london': 369,
#  'young': 370,
#  'photo': 371,
#  'full': 372,
#  'thursday': 373,
#  'yourself': 374,
#  'moment': 375,
#  'same': 376,
#  'money': 377,
#  'gay': 378,
#  'sexy': 379,
#  'euro2016': 380,
#  'job': 381,
#  'wo': 382,
#  'dads': 383,
#  'omg': 384,
#  'gon': 385,
#  'house': 386,
#  'sleep': 387,
#  'tbt': 388,
#  'looks': 389,
#  'pa': 390,
#  'against': 391,
#  'said': 392,
#  'obama': 393,
#  'fuck': 394,
#  'politics': 395,
#  'try': 396,
#  'mom': 397,
#  'hours': 398,
#  'listen': 399,
#  'conference': 400,
#  'thought': 401,
#  'making': 402,
#  'already': 403,
#  'june': 404,
#  'wonderful': 405,
#  'gorilla': 406,
#  'tweets': 407,
#  'mind': 408,
#  'pretty': 409,
#  'working': 410,
#  'porn': 411,
#  'stay': 412,
#  'shooting': 413,
#  'since': 414,
#  'body': 415,
#  'both': 416,
#  'also': 417,
#  'nude': 418,
#  'season': 419,
#  'fitness': 420,
#  'depression': 421,
#  'words': 422,
#  'loved': 423,
#  'couple': 424,
#  'children': 425,
#  'poetry': 426,
#  'gone': 427,
#  'tear': 428,
#  'head': 429,
#  'perfect': 430,
#  'run': 431,
#  'quotes': 432,
#  'shit': 433,
#  'woman': 434,
#  'inspiration': 435,
#  'which': 436,
#  'guy': 437,
#  'few': 438,
#  'country': 439,
#  'racist': 440,
#  'each': 441,
#  'beauty': 442,
#  'hour': 443,
#  'environment': 444,
#  'cold': 445,
#  'enough': 446,
#  'cat': 447,
#  'read': 448,
#  'truth': 449,
#  'says': 450,
#  'must': 451,
#  'dance': 452,
#  'through': 453,
#  'relax': 454,
#  'yay': 455,
#  'w': 456,
#  'meet': 457,
#  'mood': 458,
#  'times': 459,
#  'âx80x93': 460,
#  'dead': 461,
#  'x': 462,
#  'post': 463,
#  'hey': 464,
#  'buy': 465,
#  'myself': 466,
#  'open': 467,
#  'till': 468,
#  'while': 469,
#  'crazy': 470,
#  'rest': 471,
#  'retweet': 472,
#  'simulation': 473,
#  'simulator': 474,
#  'adapt': 475,
#  'men': 476,
#  'gift': 477,
#  'else': 478,
#  'trip': 479,
#  'use': 480,
#  'loving': 481,
#  'super': 482,
#  'dream': 483,
#  'together': 484,
#  'media': 485,
#  'celebrate': 486,
#  'song': 487,
#  'smiles': 488,
#  'bed': 489,
#  'son': 490,
#  'ðx9fx98x81': 491,
#  'trying': 492,
#  'shop': 493,
#  'flowers': 494,
#  'put': 495,
#  'remember': 496,
#  'wednesday': 497,
#  'share': 498,
#  'movie': 499,
#  'usa': 500,
#  'others': 501,
#  'liberal': 502,
#  'anything': 503,
#  'photography': 504,
#  'tell': 505,
#  'sorry': 506,
#  'actually': 507,
#  'coffee': 508,
#  'goes': 509,
#  'month': 510,
#  'thoughts': 511,
#  'allahsoil': 512,
#  'lives': 513,
#  'call': 514,
#  'far': 515,
#  'race': 516,
#  'business': 517,
#  'ppl': 518,
#  'sick': 519,
#  'months': 520,
#  'tickets': 521,
#  'nature': 522,
#  'yesterday': 523,
#  'instagram': 524,
#  'empty': 525,
#  'sweet': 526,
#  'needs': 527,
#  'sure': 528,
#  'almost': 529,
#  'gym': 530,
#  'comes': 531,
#  'seeing': 532,
#  'wrong': 533,
#  'fact': 534,
#  'tweet': 535,
#  'hear': 536,
#  'reading': 537,
#  'anyone': 538,
#  'toptags': 539,
#  'ðx9fx98x82': 540,
#  'alone': 541,
#  'tgif': 542,
#  'talk': 543,
#  'came': 544,
#  'single': 545,
#  'places': 546,
#  'car': 547,
#  'lgbt': 548,
#  'power': 549,
#  'goodmorning': 550,
#  'evening': 551,
#  'anymore': 552,
#  'ðx9fx98': 553,
#  'hardcore': 554,
#  'child': 555,
#  '7': 556,
#  'sunshine': 557,
#  '1st': 558,
#  'latest': 559,
#  'story': 560,
#  'fans': 561,
#  'side': 562,
#  '6': 563,
#  'gun': 564,
#  'join': 565,
#  'running': 566,
#  'daily': 567,
#  'forever': 568,
#  'aww': 569,
#  'lifestyle': 570,
#  'tired': 571,
#  'nervous': 572,
#  'daddy': 573,
#  'sunny': 574,
#  'kind': 575,
#  'racism': 576,
#  '50': 577,
#  'high': 578,
#  'tuesday': 579,
#  'uk': 580,
#  'saw': 581,
#  'gets': 582,
#  'football': 583,
#  'birds': 584,
#  'under': 585,
#  'hello': 586,
#  'prayfororlando': 587,
#  'ago': 588,
#  'ðx9fx98x94': 589,
#  'delete': 590,
#  'green': 591,
#  'b': 592,
#  'went': 593,
#  'less': 594,
#  'followers': 595,
#  'care': 596,
#  'order': 597,
#  'blue': 598,
#  'app': 599,
#  'impoant': 600,
#  'cry': 601,
#  'leads': 602,
#  'vacation': 603,
#  'boys': 604,
#  'social': 605,
#  'lunch': 606,
#  'daughter': 607,
#  'favorite': 608,
#  'matter': 609,
#  'suppo': 610,
#  'special': 611,
#  'booked': 612,
#  'boyfriend': 613,
#  'ðx9fx92x95': 614,
#  'whole': 615,
#  'nyc': 616,
#  'mean': 617,
#  'depressed': 618,
#  'yall': 619,
#  'useful': 620,
#  'ok': 621,
#  'despite': 622,
#  'youtube': 623,
#  'early': 624,
#  'act': 625,
#  '20': 626,
#  'smiling': 627,
#  'reason': 628,
#  'ðx9fx98x80': 629,
#  'death': 630,
#  'sea': 631,
#  'visit': 632,
#  'conce': 633,
#  'late': 634,
#  'fucking': 635,
#  'victims': 636,
#  'lucky': 637,
#  'become': 638,
#  'laugh': 639,
#  'organizations': 640,
#  'word': 641,
#  'arrived': 642,
#  'seen': 643,
#  'cause': 644,
#  'later': 645,
#  'afternoon': 646,
#  'dont': 647,
#  'wishing': 648,
#  'hu': 649,
#  'set': 650,
#  'complete': 651,
#  'prayers': 652,
#  'tv': 653,
#  'sjw': 654,
#  'bit': 655,
#  'pic': 656,
#  'disney': 657,
#  'anxiety': 658,
#  'vs': 659,
#  'sometimes': 660,
#  'red': 661,
#  'once': 662,
#  'future': 663,
#  'cultureofdevelopment': 664,
#  'understand': 665,
#  'deletetweets': 666,
#  'damn': 667,
#  'walk': 668,
#  'style': 669,
#  'stas': 670,
#  'florida': 671,
#  'guns': 672,
#  'xxx': 673,
#  'eyes': 674,
#  'guess': 675,
#  'date': 676,
#  'ðx9fx98x98': 677,
#  'vine': 678,
#  'happened': 679,
#  '12': 680,
#  'garden': 681,
#  'seems': 682,
#  'welcome': 683,
#  'maybe': 684,
#  'finished': 685,
#  'state': 686,
#  'point': 687,
#  'brexit': 688,
#  'smh': 689,
#  'bring': 690,
#  'group': 691,
#  'shopping': 692,
#  'snapchat': 693,
#  'stuff': 694,
#  'history': 695,
#  'mad': 696,
#  'though': 697,
#  'ass': 698,
#  'education': 699,
#  '30': 700,
#  'cantwait': 701,
#  'park': 702,
#  'safe': 703,
#  '2nd': 704,
#  'wan': 705,
#  'pray': 706,
#  'reached': 707,
#  'dinner': 708,
#  'design': 709,
#  'close': 710,
#  'taking': 711,
#  'orlandoshooting': 712,
#  'happen': 713,
#  'animals': 714,
#  'event': 715,
#  'homes': 716,
#  'memories': 717,
#  'saying': 718,
#  'picoftheday': 719,
#  'final': 720,
#  'choose': 721,
#  'learn': 722,
#  '8': 723,
#  'nasty': 724,
#  'everyday': 725,
#  'lawofattraction': 726,
#  'flag': 727,
#  'feelings': 728,
#  'able': 729,
#  'comments': 730,
#  'training': 731,
#  'freedom': 732,
#  'staing': 733,
#  'killed': 734,
#  'lover': 735,
#  'mountains': 736,
#  'goals': 737,
#  'picture': 738,
#  'anniversary': 739,
#  'hillary': 740,
#  'truly': 741,
#  'top': 742,
#  'wants': 743,
#  'y': 744,
#  'name': 745,
#  'cake': 746,
#  '100': 747,
#  'soul': 748,
#  'wanted': 749,
#  'sister': 750,
#  'break': 751,
#  'fan': 752,
#  'called': 753,
#  'families': 754,
#  'âx80x94': 755,
#  'parents': 756,
#  'actor': 757,
#  'thankyou': 758,
#  'view': 759,
#  'chase': 760,
#  'source': 761,
#  'easy': 762,
#  'heard': 763,
#  'mother': 764,
#  'officially': 765,
#  'half': 766,
#  'suppoers': 767,
#  'film': 768,
#  'yoga': 769,
#  'vote': 770,
#  'dreams': 771,
#  'color': 772,
#  'happening': 773,
#  'giving': 774,
#  'fresh': 775,
#  'small': 776,
#  'vicinity': 777,
#  'reality': 778,
#  'update': 779,
#  'sky': 780,
#  'tragic': 781,
#  'club': 782,
#  'july': 783,
#  'talking': 784,
#  'thinking': 785,
#  'photos': 786,
#  'bless': 787,
#  'cant': 788,
#  'ðx9fx94x9d': 789,
#  'save': 790,
#  'slut': 791,
#  'ramadan': 792,
#  'ahead': 793,
#  'crying': 794,
#  'voice': 795,
#  'police': 796,
#  'pathetic': 797,
#  'takes': 798,
#  'moving': 799,
#  'bought': 800,
#  'shows': 801,
#  'episode': 802,
#  'mine': 803,
#  'feels': 804,
#  '2017': 805,
#  'exciting': 806,
#  'meeting': 807,
#  'affirmations': 808,
#  'instead': 809,
#  'england': 810,
#  'national': 811,
#  'brother': 812,
#  'shot': 813,
#  'workout': 814,
#  'broken': 815,
#  'lonely': 816,
#  'community': 817,
#  'rain': 818,
#  'president': 819,
#  'dogs': 820,
#  'kill': 821,
#  'forget': 822,
#  'dj': 823,
#  'phone': 824,
#  'happier': 825,
#  'busy': 826,
#  'tragedy': 827,
#  'lighttherapy': 828,
#  'missing': 829,
#  'service': 830,
#  'heal': 831,
#  'bday': 832,
#  'wake': 833,
#  'hit': 834,
#  'past': 835,
#  'india': 836,
#  'dear': 837,
#  'won': 838,
#  'hell': 839,
#  'instamood': 840,
#  'yo': 841,
#  'die': 842,
#  'target': 843,
#  'line': 844,
#  'dark': 845,
#  'control': 846,
#  'star': 847,
#  'leaving': 848,
#  'moments': 849,
#  'nbafinals': 850,
#  'used': 851,
#  'fear': 852,
#  '3d': 853,
#  'ðx9fx98x84': 854,
#  'horny': 855,
#  'shy': 856,
#  'blonde': 857,
#  'hatred': 858,
#  'lose': 859,
#  'makeup': 860,
#  'minutes': 861,
#  'light': 862,
#  'bc': 863,
#  'breakfast': 864,
#  'o': 865,
#  'students': 866,
#  'ask': 867,
#  'drink': 868,
#  'france': 869,
#  'ones': 870,
#  'ðx9fx98x8e': 871,
#  'hill': 872,
#  'human': 873,
#  'pain': 874,
#  'simple': 875,
#  'gorgeous': 876,
#  'sunset': 877,
#  'videos': 878,
#  'wishes': 879,
#  'loss': 880,
#  'glad': 881,
#  'official': 882,
#  'gop': 883,
#  'naughty': 884,
#  'kinky': 885,
#  'wet': 886,
#  'experience': 887,
#  '9': 888,
#  'leadership': 889,
#  'ripchristina': 890,
#  'friendship': 891,
#  'course': 892,
#  'instadaily': 893,
#  'disappointed': 894,
#  'ways': 895,
#  'rock': 896,
#  'american': 897,
#  'fit': 898,
#  'along': 899,
#  'trending': 900,
#  'americans': 901,
#  'room': 902,
#  'move': 903,
#  'campaign': 904,
#  'spend': 905,
#  'respect': 906,
#  'bitch': 907,
#  'everybody': 908,
#  'least': 909,
#  'stand': 910,
#  'died': 911,
#  'gbp': 912,
#  'husband': 913,
#  'blur': 914,
#  'punjab': 915,
#  'huge': 916,
#  'wonder': 917,
#  'mass': 918,
#  'naked': 919,
#  'luck': 920,
#  'during': 921,
#  'p': 922,
#  'udtapunjab': 923,
#  'seriously': 924,
#  'wife': 925,
#  'present': 926,
#  'vegas': 927,
#  'survive': 928,
#  'staed': 929,
#  'worst': 930,
#  'ride': 931,
#  'jobs': 932,
#  'finding': 933,
#  'fantastic': 934,
#  'ðx9fx98x83': 935,
#  'japan': 936,
#  'festival': 937,
#  'haha': 938,
#  'beer': 939,
#  'rooster': 940,
#  'vast': 941,
#  'list': 942,
#  'different': 943,
#  'political': 944,
#  'teen': 945,
#  'needed': 946,
#  'shame': 947,
#  'la': 948,
#  'islam': 949,
#  'missed': 950,
#  'inspirational': 951,
#  'reach': 952,
#  'agree': 953,
#  'violence': 954,
#  'energy': 955,
#  'local': 956,
#  'listening': 957,
#  'online': 958,
#  'decided': 959,
#  'content': 960,
#  'wtf': 961,
#  'expanse': 962,
#  'flower': 963,
#  'street': 964,
#  'launch': 965,
#  'kid': 966,
#  't': 967,
#  'pussy': 968,
#  'customer': 969,
#  'fall': 970,
#  'ðx9fx98xad': 971,
#  'wine': 972,
#  'gave': 973,
#  'calling': 974,
#  'internet': 975,
#  'joke': 976,
#  'paris': 977,
#  'tech': 978,
#  'vegan': 979,
#  'send': 980,
#  'class': 981,
#  'behind': 982,
#  'flight': 983,
#  'lots': 984,
#  'camp': 985,
#  'stuck': 986,
#  'either': 987,
#  'met': 988,
#  'tears': 989,
#  'congrats': 990,
#  'games': 991,
#  'rather': 992,
#  'using': 993,
#  'inshot': 994,
#  'facebook': 995,
#  'sign': 996,
#  'e': 997,
#  'turn': 998,
#  'oitnb': 999,
#  'three': 1000,
#  ...}

# %%
import numpy as np


def text_to_sequence(text, maxlen):
    result = []
    tokens = word_tokenize(text.lower())
    tokens_filtered = [word for word in tokens if word.isalnum()]
    for word in tokens_filtered:
        if word in vocabulary:
            result.append(vocabulary[word])

    padding = [0] * (maxlen-len(result))
    return result[-maxlen:] + padding

# %%
max_len = 20

x_train = np.asarray([text_to_sequence(text, max_len) for text in df_train["tweet"]])
x_val = np.asarray([text_to_sequence(text, max_len) for text in df_val["tweet"]])

# %%
x_train.shape
# Out:
# (21414, 20)

# %%
df_train['tweet'].iloc[3]
# Out:
# 'we are so for the 2nd annual bailey day taste off   join us for  familyfun  baileyday2016  mountainliving'

# %%
x_train[3]
# Out:
# array([  32,   24,   22,    8,    1,  704, 1937,   20,  134,  565,   91,
#           8,    0,    0,    0,    0,    0,    0,    0,    0])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class RNNFixedLen(nn.Module) :
    def __init__(self, vocab_size, embedding_dim=128, hidden_dim=128, use_last=True):
        super().__init__()
        self.use_last = use_last
        self.embeddings = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.rnn = nn.RNN(embedding_dim, hidden_dim, num_layers=2, batch_first=True)
        self.linear = nn.Linear(hidden_dim, 1)
        self.dropout = nn.Dropout(0.2)
        
    def forward(self, x):
        x = self.embeddings(x)
        x = self.dropout(x)

        rnn_out, ht = self.rnn(x) 
        # rnn_out: тензор с выходными фичами с последнего слоя для каждого t
        # h_t: тензор с последними скрытыми состояниями по слоям

        if self.use_last:
            last_tensor = rnn_out[:,-1,:]
        else:
            # use mean
            last_tensor = torch.mean(rnn_out[:,:], dim=1)
    
        out = self.linear(last_tensor)
        
        return torch.sigmoid(out)

# %%
rnn_init = RNNFixedLen(max_words, 128, 20, use_last=False)
optimizer = torch.optim.Adam(rnn_init.parameters(), lr=0.001)
criterion = nn.BCELoss()

# %%
from torch.utils.data import DataLoader, Dataset


class DataWrapper(Dataset):
    def __init__(self, data, target = '', transform=None):
        self.data = torch.from_numpy(data).long()
        if target != '':
          self.target = torch.from_numpy(target).long()
        self.transform = transform
        
    def __getitem__(self, index):
        x = self.data[index]
        if self.target != '':
          y = self.target[index]
  
        if self.transform:
            x = self.transform(x)
        if self.target != '':
          return x, y
        else: return x
    
    def __len__(self):
        return len(self.data)

# %%
batch_size = 512

train_dataset = DataWrapper(x_train, df_train['label'].values)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = DataWrapper(x_val, df_val['label'].values)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   import sys

# %%
train_loader

# %%
for x, l in train_loader:
    print(x.shape)
    print(l.shape)
    print(l[0])
    break
# Out:
# torch.Size([512, 20])
# torch.Size([512])
# tensor(0)

# %%
model = Net(vocab_size=max_words)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device = 'cpu'

# %%
print(model)
print("Parameters:", sum([param.nelement() for param in model.parameters()]))
# Out:
# Net(
#   (embedding): Embedding(2000, 128)
#   (conv_1): Conv1d(128, 128, kernel_size=(3,), stride=(1,))
#   (conv_2): Conv1d(128, 128, kernel_size=(4,), stride=(1,))
#   (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (linear_1): Linear(in_features=128, out_features=64, bias=True)
#   (linear_2): Linear(in_features=64, out_features=1, bias=True)
# )
# Parameters: 379265

# %%
optimizer = torch.optim.Adagrad(model.parameters(), lr=0.01)
criterion = nn.BCELoss()

# %%
# Training
epochs = 5
print_batch_n = 100

# %%
model = model.to(device)
model.train()
th = 0.5

train_loss_history = []
test_loss_history = []


for epoch in range(epochs):  
    running_items, running_right = 0.0, 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)
        
        # обнуляем градиент
        optimizer.zero_grad()
        outputs = model(inputs)
        
        loss = criterion(outputs, labels.float().view(-1, 1))
        loss.backward()
        optimizer.step()

        # подсчет ошибки на обучении
        loss = loss.item()
        running_items += len(labels)
        # подсчет метрики на обучении
        pred_labels = torch.squeeze((outputs > th).int())
        running_right += (labels == pred_labels).sum()
        
        # выводим статистику о процессе обучения
        if i % 150 == 0:    # печатаем каждые 150 batches
            model.eval()
            
            print(f'Epoch [{epoch + 1}/{epochs}]. ' \
                  f'Step [{i + 1}/{len(train_loader)}]. ' \
                  f'Loss: {loss:.3f}. ' \
                  f'Acc: {running_right / running_items:.3f}', end='. ')
            running_loss, running_items, running_right = 0.0, 0.0, 0.0
            train_loss_history.append(loss)

            # выводим статистику на тестовых данных
            test_running_right, test_running_total, test_loss = 0.0, 0.0, 0.0
            for j, data in enumerate(val_loader):
                test_labels = data[1].to(device)
                test_outputs = model(data[0].to(device))
                
                # подсчет ошибки на тесте
                test_loss = criterion(test_outputs, test_labels.float().view(-1, 1))
                # подсчет метрики на тесте
                test_running_total += len(data[1])
                pred_test_labels = torch.squeeze((test_outputs > th).int())
                test_running_right += (test_labels == pred_test_labels).sum()
            
            test_loss_history.append(test_loss.item())
            print(f'Test loss: {test_loss:.3f}. Test acc: {test_running_right / test_running_total:.3f}')
        
        model.train()
        
print('Training is finished!')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch [1/5]. Step [1/42]. Loss: 0.677. Acc: 0.725. Test loss: 0.001. Test acc: 0.930
# Epoch [2/5]. Step [1/42]. Loss: 0.183. Acc: 0.934. Test loss: 0.128. Test acc: 0.930
# Epoch [3/5]. Step [1/42]. Loss: 0.184. Acc: 0.922. Test loss: 0.012. Test acc: 0.930
# Epoch [4/5]. Step [1/42]. Loss: 0.144. Acc: 0.938. Test loss: 0.183. Test acc: 0.939
# Epoch [5/5]. Step [1/42]. Loss: 0.108. Acc: 0.961. Test loss: 0.013. Test acc: 0.944
# Training is finished!

# %%
import matplotlib.pyplot as plt

plt.title('Loss history')
plt.grid(True)
plt.ylabel('Loss')
plt.xlabel('Step')
plt.plot(train_loss_history, label='train')
plt.plot(test_loss_history, label='test')
plt.legend();

# %% [markdown]
# # Опишите, какой результат вы получили? Что помогло вам улучшить ее точность?
#
# Добрый день!
#
# Не понимаю, почему результат получается настолько неправдоподобным. Разбила выборку train на train и val, но они, вроде, не совпадают. А как на test выборке проверить не происходит ли переобучения, без верных значений "label" - не знаю.
